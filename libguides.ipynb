# %%
# scrape lib urls

from selenium import webdriver
import time
browser = webdriver.Chrome() 
browser.get('http://google.com/')
element = browser.find_element_by_id('lst-ib') 
element.send_keys("guides by subject")
element.submit()

time.sleep(2)
def get_urls_from_browser(b):
    articles = [] 
    for session in browser.find_elements_by_xpath("//div[@class='srg']//div[@class='rc']"):     
        article = {} 
        url = session.find_element_by_xpath("./h3[@class='r']/*[@href]")
        article['url'] = url.get_attribute('href') 
        articles.append(article)

    return articles
all_page_articles = []
for i in range(31):
    time.sleep(0.5)
    new_articles = get_urls_from_browser(browser) # 函数调用
    all_page_articles.extend(new_articles) # 
    browser.execute_script('window.scrollTo(0, document.body.scrollHeight/1.5);')
    next_page = browser.find_element_by_link_text('下一页')
    next_page.click()

import pandas as pd 
df = pd.DataFrame(all_page_articles)
df.to_csv('the library list.csv')

# %%
# scraper
url_list = [
            'https://libguides.library.usyd.edu.au/',
    
            'http://canterbury.libguides.com/',
            'https://researchguides.uic.edu/',
            'https://subjectguides.uwaterloo.ca/'
            'https://guides.lib.utexas.edu/',
            'https://guides.lib.monash.edu/',
            'http://guides.lib.uw.edu/research',
            'https://libguides.library.usyd.edu.au/',
            'https://infoguides.gmu.edu/',
            'https://guides.lib.uwo.ca/',
            'https://libguides.murdoch.edu.au/',
            'https://libguides.murdoch.edu.au/',
            'https://libguides.library.umaine.edu/',
            'https://libguides.lib.umanitoba.ca/',
            'https://libguides.uta.edu/',
            'https://subjectguides.library.american.edu/',
            'http://research.lib.buffalo.edu/',
            'https://libguides.depaul.edu/',
            'https://guides.lib.vt.edu/',
    
            'https://libguides.usask.ca/',
            'https://guides.lib.ua.edu/',
            'http://guides.osu.edu/',
            'https://guides.library.yale.edu/',
            'https://libguides.rug.nl/',
            'https://libguides.sjsu.edu/',
            'https://libguides.library.qut.edu.au/',
            'https://libguides.rhul.ac.uk/',
            'https://guides.library.vcu.edu/',
            'https://libguides.eku.edu/',
            'https://libguides.usc.edu/',
            'http://research.moreheadstate.edu/',
            'https://library.ucalgary.ca/guides',
            'https://guides.library.duke.edu/',
            'https://libguides.lib.cuhk.edu.hk/',
            'https://libguides.gvsu.edu/',
            'https://libguides.umflint.edu/',
            'https://libguides.scu.edu.au/',
            'http://guides.libs.uga.edu/',
            'https://guides.library.unr.edu/guides',
            'https://guides.lib.uiowa.edu/',
            'https://guides.main.library.emory.edu/',
            'http://libguides.tulane.edu/researchguides',
            'https://guides.lib.olemiss.edu/',
            'https://libguides.mnsu.edu/',
            'https://libguides.uky.edu/',
            'https://guides.lib.uh.edu/',
            'https://libguides.utk.edu/',
            'https://guides.uflib.ufl.edu/',
            'https://libguides.merrimack.edu/',
            'http://researchguides.gonzaga.edu/',
            'https://libguides.nwmissouri.edu/',
            'https://guides.lib.purdue.edu/subjects',
            'https://subjectguides.york.ac.uk/',
            'https://libguides.lib.miamioh.edu/',
            'https://libguides.wustl.edu/',
            'https://libguides.city.ac.uk/',
            'https://libraryguides.binghamton.edu/',
            'https://libguides.uvic.ca/',
            'https://libraries.psu.edu/guides/subject',
            'https://libguides.gwu.edu/',
            'http://guides.library.jhu.edu/',
            'http://guides.newman.baruch.cuny.edu/',
            'https://guides.nyu.edu/',
            'https://research.pugetsound.edu/',
            'https://researchbysubject.bucknell.edu/guides',
            'https://www.kent.ac.uk/library/subjects/',
            'https://libguides.lmu.edu/',
            'https://library.columbia.edu/subject-guides.html',
            'https://guides.library.stonybrook.edu/',
            'https://guides.library.harvard.edu/sb.php',
            'http://libguides.library.cpp.edu/',
            'https://libraryguides.oswego.edu/',
            'https://guides.library.uwa.edu.au/',
            'https://libguides.twu.edu/',
            'https://researchguides.georgebrown.ca/',
            'https://iupui.campusguides.com/',
            'https://libguides.library.nd.edu/',
            'https://researchguides.library.syr.edu/',
            'https://guides.library.uncc.edu/',
            'https://libguides.exeter.ac.uk/',
            'http://guides.library.unlv.edu/',
            'https://guides.library.lincoln.ac.uk/',
            'https://libguides.derby.ac.uk/',
            'https://libguides.du.edu/',
            'https://guides.library.tamucc.edu/',
            'http://researchguides.library.vanderbilt.edu/',
            'https://guides.library.umass.edu/',
            'https://guides.library.ubc.ca/',
            'https://libguides.library.kent.edu/',
            'http://guides.library.uq.edu.au/',
            'https://guides.library.ucsc.edu/',
            'https://libguides.mq.edu.au/',
            'http://researchguides.uvm.edu/',
            'https://guides.lib.usf.edu/',
            'http://libguides.gatech.edu/',
            'https://guides.lib.calpoly.edu/',
            'http://libguides.bates.edu/',
            'https://guides.library.illinois.edu/',
            'https://guides.lib.k-state.edu/',
            'https://libguides.dundee.ac.uk/',
            'http://libguides.mdx.ac.uk/',
            'https://uwm.edu/libraries/databases/',
            'https://libguides.ucmerced.edu/',
            'https://libguides.sfasu.edu/',
            'https://library.acu.edu.au/find/subject_guides',
            'http://libguides.richmond.edu/',
            'https://libguides.northwestern.edu/',
            'https://guides.library.ualberta.ca/',
            'https://libguides.napier.ac.uk/',
            'https://researchguides.uoregon.edu/',
            'https://libguides.rutgers.edu/',
            'https://libguides.uos.ac.uk/',
            'https://wmich.edu/library/collections/databases',
            'https://libguides.stonehill.edu/',
            'http://libguides.csu.edu.au/',
            'https://subjectguides.ara.ac.nz/',
            'https://lib.guides.umd.edu/',
            'http://libguides.mst.edu/',
            'https://libguides.csuchico.edu/',
            'http://guides.lib.uchicago.edu/',
            'https://www.mcgill.ca/library/find/subjects',
            'https://guides.library.durhamcollege.ca/',
            'https://research.library.gsu.edu/',
            'http://research.un.org/',
            'https://libguides.uwf.edu/',
            'https://guides.library.oregonstate.edu/',
            'https://libguides.wooster.edu/',
            'https://guides.library.ttu.edu/',
            'https://anulib.anu.edu.au/find-access/subject-guides',
            'http://guides.temple.edu/',
            'https://www.lib.umn.edu/subjects/',
            'https://guides.library.uab.edu/',
            'https://guides.ucsf.edu/',
            'https://libguides.mines.edu/',
            'https://guides.aclibrary.org/',
            'https://libguides.regis.edu/',
            'https://library.uncg.edu/research/guides/',
            'http://libguides.uttyler.edu/',
            'https://libguides.cdu.edu.au/',
            'https://guides.library.manoa.hawaii.edu/',
            'http://library.bu.edu/guides',
            'http://libguides.bcu.ac.uk/',
            'https://courseguides.trincoll.edu/',
            'https://researchguides.dartmouth.edu/',
            'https://researchguides.smu.edu.sg/',
            'http://libguides.umw.edu/',
            'https://libraryguides.helsinki.fi/',
            'https://culibraries.creighton.edu/',
            'https://libguides.tru.ca/',
            'https://libguides.uwinnipeg.ca/',
            'https://libguides.smu.ca/',
            'https://campusguides.lib.utah.edu/',
            'https://libguides.furman.edu/bysubject',
            'https://libguides.brown.edu/',
            'https://libguides.library.winthrop.edu/',
            'https://www.ucl.ac.uk/library/subject-support/guides',
            'https://libguides.nvcc.edu/',
            'http://libguides.whitworth.edu/',
            'https://lib.siena.edu/libguides',
            'https://libguides.memphis.edu/',
            'https://guides.library.fresnostate.edu/',
            'http://libguides.scf.edu/',
            'https://guides.library.sc.edu/',
            'https://libguides.kpu.ca/',
            'https://libguides.csun.edu/',
            'http://guides.library.mun.ca/',
            'https://www.newcastle.edu.au/library/access/subject-research-guides',
            'https://libguides.atu.edu/',
            'https://guides.lib.uconn.edu/',
            'https://libguides.nps.edu/',
            'https://libguides.seattleu.edu/',
            'https://libguides.brescia.edu/',
            'https://guides.library.pdx.edu/',
            'https://libguides.salemstate.edu/',
            'https://libguides.coventry.ac.uk/',
            'https://libguides.unomaha.edu/',
            'http://researchguides.njit.edu/',
            'https://www.concordia.ca/library/guides.html',
            'https://libguides.oxy.edu/',
            'http://libguides.msvu.ca/',
            'https://subjectguides.nscc.ca/',
            'https://guides.library.ucla.edu/',
            'https://guides.lib.udel.edu/',
            'http://libguides.lib.umt.edu/',
            'https://libguides.unm.edu/',
            'https://guides.mtholyoke.edu/',
            'https://libraryguides.unh.edu/',
            'https://library.worc.ac.uk/subject-guides',
            'https://guides.emich.edu/',
            'https://researchguides.case.edu/',
            'https://libguides.brunel.ac.uk/',
            'https://libguides.aacc.edu/',
            'http://libraryresources.unog.ch/',
            'https://libguides.murraystate.edu/',
            'https://libguides.libraries.wsu.edu/',
            'https://libguides.tncc.edu/',
            'https://libguides.cmich.edu/',
            'https://researchguides.library.tufts.edu/hhsl',
            'https://libguides.mjc.edu/',
            'https://libguides.wvu.edu/',
            'http://subjectguides.library.unsw.edu.au/subjectguides',
            'https://libraryguides.lehigh.edu/',
            'https://libguides.fau.edu/',
            'https://libraryguides.griffith.edu.au/',
            'https://libguides.wlu.edu/',
            'https://libguides.denison.edu/',
            'https://libguides.pace.edu/',
            'https://www.catholicresearch.org/subject-guides',
            'https://libguides.gwumc.edu/',
            'https://libguides.tcc.edu/',
            'https://libguides.colostate.edu/',
            'http://libguides.unitec.ac.nz/',
            'http://www.lse.ac.uk/Library/Collections/Subject-guides',
            'https://www.internationalstudent.com/study-centers/subject-guide/',
            'https://libguides.wellesley.edu/',
            'https://guides.zsr.wfu.edu/',
            'https://guides.libraries.uc.edu/',
            'https://libguides.southernct.edu/',
            'https://libguides.auburn.edu/',
            'http://southernlibrarianship.icaap.org/content/v09n03/tchangalova_n01.html',
            'https://guides.lib.fsu.edu/',
            'http://libguides.luc.edu/',
            'https://libraryguides.goucher.edu/',
            'https://library.soton.ac.uk/home/subjects',
            'http://libguides.usd.edu/',
            'http://libguides.utsa.edu/',
            'http://guides.sl.nsw.gov.au/',
            'http://libguides.mcmaster.ca/',
            'https://libguides.slu.edu/',
            'http://www.library.manchester.ac.uk/search-resources/subject-guides/',
            'https://libguides.bhtafe.edu.au/',
            'http://libguides.bgsu.edu/',
            'http://libraryguides.uwsp.edu/',
            'https://libguides.lehman.edu/',
            'https://www.library.ucdavis.edu/browse-subjects/',
            'https://libguides.mmu.ac.uk/subjectguides',
            'https://www.gcu.ac.uk/library/subjecthelp/subjectguides/',
            'https://targetcareers.co.uk/uni/degree-subject-guides',
            'http://www.sussex.ac.uk/library/guides',
            'https://resources.library.lemoyne.edu/',
            'https://libguides.roanoke.edu/',
            'https://lib.de.us/subject-guides/',
            'https://www.topuniversities.com/qs-world-university-rankings',
            'https://www.thecompleteuniversityguide.co.uk/league-tables/rankings',
            'https://www.thecompleteuniversityguide.co.uk/',
            'https://libguides.uwc.ac.za/',
            'https://www.polyu.edu.hk/as/subj_reg/Guide_for_Subject_Registration.pdf',
            'https://books.google.com.hk/books?id=QfuXxvAAP34C&pg=PA4&lpg=PA4&dq=guides+by+subject&source=bl&ots=dki3IQKd3C&sig=7sXXQPuObJlv8F5GLUvJ30eXaTk&hl=zh-CN&sa=X&ved=2ahUKEwit4ZjI8cjdAhXJzmEKHeA-D-Y48AEQ6AEwBnoECAAQAQ',
            'http://trexler.muhlenberg.edu/',
            'https://books.google.com.hk/books?id=objhCokcExoC&pg=PA71&lpg=PA71&dq=guides+by+subject&source=bl&ots=gIJZj2gF1W&sig=gC09km1PmJ7JKp3OBQ441FNyQok&hl=zh-CN&sa=X&ved=2ahUKEwit4ZjI8cjdAhXJzmEKHeA-D-Y48AEQ6AEwCHoECAIQAQ',
            'https://www.lib.jmu.edu/',
            'http://www.lib.cam.ac.uk/eresources/',
            'https://developer.android.com/guide/',
            'https://books.google.com.hk/books?id=G_nDHA4ibNoC&pg=PA17&lpg=PA17&dq=guides+by+subject&source=bl&ots=yBXlC0ADV1&sig=RLh8nhbEWQUd3hQYOSjGy__6X-E&hl=zh-CN&sa=X&ved=2ahUKEwi4nfbI8cjdAhVQZt4KHZhYB-c4-gEQ6AEwAnoECAgQAQ',
            'https://books.google.com.hk/books?id=3cGqldz0NMMC&pg=PA182&lpg=PA182&dq=guides+by+subject&source=bl&ots=ugPFo8X2i3&sig=6pC-iKPJ-IVdghiGzV0QlGjkjMw&hl=zh-CN&sa=X&ved=2ahUKEwi4nfbI8cjdAhVQZt4KHZhYB-c4-gEQ6AEwA3oECAcQAQ',
            'https://books.google.com.hk/books?id=mN3CBpRwowsC&pg=PA25&lpg=PA25&dq=guides+by+subject&source=bl&ots=u-JQylz4I6&sig=76W3RX3kZ-wblHOZ-JwDnlIKmao&hl=zh-CN&sa=X&ved=2ahUKEwi4nfbI8cjdAhVQZt4KHZhYB-c4-gEQ6AEwBHoECAQQAQ',
            'https://academicguides.waldenu.edu/library',
            'https://books.google.com.hk/books?id=-aG0MQ_ApN4C&pg=PR1&lpg=PR1&dq=guides+by+subject&source=bl&ots=HHrtEoSzXq&sig=tImARvuRb74q9M56_CBkoS38cU4&hl=zh-CN&sa=X&ved=2ahUKEwi4nfbI8cjdAhVQZt4KHZhYB-c4-gEQ6AEwBnoECAAQAQ',
            'https://www.nature.com/articles/d41586-018-06628-2',
            'https://lms.unimelb.edu.au/home',
            'http://www.ibo.org/programmes/diploma-programme/curriculum/theory-of-knowledge/',
            'https://www.ncbi.nlm.nih.gov/books/NBK3827/',
            'https://www.gov.uk/guidance/specialist-leaders-of-education-a-guide-for-potential-applicants',
            'https://www.ukdataservice.ac.uk/use-data/guides/thematic-guides',
            'https://www.bbc.com/bitesize',
            'https://en.wikipedia.org/wiki/List_of_Dewey_Decimal_classes',
            'https://www.findaphd.com/study-abroad/asia/phd-study-in-india.aspx',
            'https://www.rte.ie/about/en/policies-and-reports/policies-guidelines/2012/0417/317412-rte-data-protection-policy/',
            'https://www.sparknotes.com/lit/',
            'https://library.ucr.edu/',
            'https://developers.google.com/style/',
            'https://library.villanova.edu/research/librarians/linda-hauck',
            'https://library.villanova.edu/',
            'https://www.scholastic.com/teachers/student-activities/',
            'https://collegereadiness.collegeboard.org/sat-subject-tests/register/test-dates-deadlines',
            'https://www.ets.org/gre',
            'https://www.vcaa.vic.edu.au/Pages/vce/studies/index.aspx',
            'https://writingcenter.unc.edu/tips-and-tools/thesis-statements/',
            'https://material.io/',
            'https://www.ucas.com/',
            'https://www.irs.gov/businesses/railroad-retirement-tax-act-rrta-desk-guide-january-2009',
            'https://moz.com/beginners-guide-to-seo',
            'https://www.library.pitt.edu/phd-and-grad-study-online-request-form',
            'https://www.hhs.gov/ohrp/regulations-and-policy/belmont-report/index.html',
            'https://www.h-net.org/jobs/job_display.php?id=57340',
            'http://www.artcyclopedia.com/',
            'https://www.fitbit.com/store',
            'http://www.wweek.com/culture/2018/09/19/in-anticipation-of-her-trump-tell-all-stormy-daniels-was-made-the-subject-of-a-portland-produced-comic-book/',
            'https://www.lynda.com/',
            'https://www.cxc.org/',
            'https://www.oaic.gov.au/privacy-law/privacy-act/notifiable-data-breaches-scheme',
            'https://techcommunity.microsoft.com/t5/IT-Resources-Training-Blog/The-Microsoft-365-Enterprise-Deployment-Guide/ba-p/255396',
            'https://www.travelandleisure.com/travel-tips/mobile-apps/lyfx-app-connects-travelers-with-local-guides-outdoor-adventures',
            'https://www.santasvillage.ca/',
            'https://www.thewestmorlandgazette.co.uk/news/national/16889091.cuts-in-s4-subject-choices-impacting-on-pupils-committee-told/',
            'https://angular.io/docs',
            'https://www.preprints.org/manuscript/201809.0342/v1',
            'http://buschgardens.com/williamsburg/help/guests-with-disabilities/',
            'https://kahoot.com/',
            'https://towardsdatascience.com/deep-learning-for-beginners-practical-guide-with-python-and-keras-d295bfca4487',
            'https://disneyworld.disney.go.com/en-eu/calendars/',
            'https://www.supercars.com/auckland/event-guide/',
      #      'https://www.gazetteandherald.co.uk/news/national/16889091.cuts-in-s4-subject-choices-impacting-on-pupils-committee-told/',
            'https://my.christchurchcitylibraries.com/blogs/post/podcast-suffrage-125/',
            'https://www.jbe-platform.com/content/lin-biblio',
            'https://streeteasy.com/building/3-clinton-street-new_york/07',
            'http://www.chaffeecountytimes.com/free_content/recycling-center-to-be-subject-of-trustee-coffee/article_463cf000-bc2c-11e8-b466-63d5d7564a43.html',
            'https://www.1843magazine.com/culture/cheats-guide/to-all-the-boys-ive-loved-before-a-cheats-guide',
            'https://www.denverpost.com/2018/09/19/colorado-serial-killer-scott-kimball-on-dateline-nbc/',
            'https://www.tomsguide.com/us/iphone-xs-iphone-xs-max-benchmarks,review-5745.html',
            'https://www.golf.com/courses-and-travel/2018/09/19/tipping-golf-course-ultimate-guide-tips/']


import pandas as pd 
import csv
from selenium import webdriver  
from selenium.common.exceptions import NoSuchElementException  
from selenium.common.exceptions import ElementNotVisibleException
from selenium.common.exceptions import StaleElementReferenceException
import time  
import re
browser = webdriver.Chrome()
import csv
from selenium import webdriver  
from selenium.common.exceptions import NoSuchElementException  
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import ElementNotVisibleException
from selenium.common.exceptions import StaleElementReferenceException
import time  
import re
browser = webdriver.Chrome()
def find_all_lib(i):
    
    # 以下是一个subject的内容
        browser.get(i)    
        el_category = browser.find_elements_by_css_selector('div.panel.panel-default')[0] # 总是索引第一个
        el_category.find_element_by_css_selector('div.bold').text
        el_category.click()# 直接这样就可以click了 但也要click才能够索取到下一级的内容
        el_a = el_category.find_elements_by_css_selector('ul.s-lg-guide-list li a')[0] 
        el_a.text, el_a.get_attribute('href')
        el_a.text
    # 用double loop来爬取所有subject的内容
        subjects = []

        el_categories = browser.find_elements_by_css_selector('div.panel.panel-default')
        for el_category in el_categories:
            category = el_category.find_element_by_css_selector('div.bold').text
            el_category.click()
            time.sleep(1)    
            el_as = el_category.find_elements_by_css_selector('ul.s-lg-guide-list li a')
            for el_a in el_as:
                subject = el_a.text
                link = el_a.get_attribute('href')
                subjects.append((category, subject, link))
        s = i.replace('/',' ').replace(':',' ')
        df = pd.DataFrame(subjects, columns=['Category', 'Subject', 'Link'])
        df.to_csv('{}.csv'.format(s))
        

success_url = []
fail_url = []
for i in url_list:
    try:
        find_all_lib(i)
        success_url.append(i)
        
    except IndexError:
        print('IndexError on URL:', i)
        fail_url.append(i)  
    
    except ElementNotVisibleException:
        print('ElementNotVisibleExceptio:', i)
        fail_url.append(i)
    except StaleElementReferenceException:
        print('StaleElementReferenceException:', i)
        fail_url.append(i)
    except WebDriverException:
        print('WebDriverException:', i)
        fail_url.append(i)

df = pd.DataFrame(success_url)
df.to_csv('success_url.csv')

dfs = pd.DataFrame(fail_url)
dfs.to_csv('fail_url.csv')



# index error 分为三种： 1 明显不是图书馆的网址 2 页面与哥伦比亚的类似 3 页面与utexas类似 但是会和CUHK一样报错index error

# WebDriverException 1 需要翻页的  2 爬了一部分然后开始出错的 https://libguides.usask.ca/?b=s
# Out:
# IndexError on URL: https://libguides.library.usyd.edu.au/http://canterbury.libguides.com/
# StaleElementReferenceException: https://researchguides.uic.edu/
# IndexError on URL: https://subjectguides.uwaterloo.ca/https://guides.lib.utexas.edu/
# IndexError on URL: http://guides.lib.uw.edu/research
# ElementNotVisibleExceptio: https://libguides.library.usyd.edu.au/
# StaleElementReferenceException: https://infoguides.gmu.edu/
# IndexError on URL: https://libguides.murdoch.edu.au/
# IndexError on URL: https://libguides.depaul.edu/
# WebDriverException: https://libguides.usask.ca/
# StaleElementReferenceException: http://guides.osu.edu/
# StaleElementReferenceException: https://guides.library.yale.edu/
# StaleElementReferenceException: https://libguides.rhul.ac.uk/
# IndexError on URL: https://libguides.eku.edu/
# WebDriverException: https://library.ucalgary.ca/guides
# IndexError on URL: https://libguides.lib.cuhk.edu.hk/
# WebDriverException: https://libguides.gvsu.edu/
# ...

# %%
# Testing: scrape all index error again

url_list = [     
     'https://libguides.slu.edu/',
    'https://libguides.unm.edu/',
'https://library.worc.ac.uk/subject-guides',
'https://www.library.ucdavis.edu/browse-subjects/',
'https://libguides.mmu.ac.uk/subjectguides',
'https://www.gcu.ac.uk/library/subjecthelp/subjectguides/',
'https://targetcareers.co.uk/uni/degree-subject-guides',
'http://www.sussex.ac.uk/library/guides',
    'https://lib.de.us/subject-guides/',
'https://www.topuniversities.com/qs-world-university-rankings',
'https://www.thecompleteuniversityguide.co.uk/league-tables/rankings',
'https://www.thecompleteuniversityguide.co.uk/',
'https://libguides.uwc.ac.za/',
    
'https://library.soton.ac.uk/home/subjects',

'http://www.library.manchester.ac.uk/search-resources/subject-guides/',
    'https://libguides.cmich.edu/',
'https://researchguides.library.tufts.edu/hhsl',
'https://libguides.mjc.edu/',
'http://subjectguides.library.unsw.edu.au/subjectguides',
'https://www.catholicresearch.org/subject-guides',
'http://libguides.unitec.ac.nz/',
'http://www.lse.ac.uk/Library/Collections/Subject-guides',
'https://www.internationalstudent.com/study-centers/subject-guide/',
'https://guides.zsr.wfu.edu/',
       'https://libguides.library.usyd.edu.au/',
    'http://guides.lib.uw.edu/research',
    'https://libguides.eku.edu/',
    'https://libguides.lib.cuhk.edu.hk/',
'https://guides.library.unr.edu/guides',
'https://guides.lib.uiowa.edu/',
'https://guides.main.library.emory.edu/',
'http://libguides.tulane.edu/researchguides',
'https://guides.lib.olemiss.edu/',
 'https://guides.lib.purdue.edu/subjects',
'https://subjectguides.york.ac.uk/',
'https://libguides.wustl.edu/',
'https://libguides.city.ac.uk/',
'https://libraryguides.binghamton.edu/',
'https://libraries.psu.edu/guides/subject',
    'https://research.pugetsound.edu/',
    'https://www.kent.ac.uk/library/subjects/',
#     'https://library.columbia.edu/subject-guides.html',
    'https://guides.library.harvard.edu/sb.php',
'https://libguides.du.edu/',
'https://guides.library.tamucc.edu/',
'http://researchguides.library.vanderbilt.edu/',
'https://guides.library.ubc.ca/',
    'https://uwm.edu/libraries/databases/',
    'https://libguides.sfasu.edu/',
    'https://wmich.edu/library/collections/databases',
'http://libguides.csu.edu.au/',
'IndexError on URL: https://subjectguides.ara.ac.nz/',
'IndexError on URL: https://lib.guides.umd.edu/',
    'http://guides.lib.uchicago.edu/',
'https://www.mcgill.ca/library/find/subjects',
'https://research.library.gsu.edu/',
    'https://guides.library.oregonstate.edu/',
'https://anulib.anu.edu.au/find-access/subject-guides',
'https://www.lib.umn.edu/subjects/',
'https://library.uncg.edu/research/guides/',
'https://guides.library.manoa.hawaii.edu/',
'http://library.bu.edu/guides',
'https://libguides.uwinnipeg.ca/',
'https://www.ucl.ac.uk/library/subject-support/guides',
'https://lib.siena.edu/libguides',
'https://www.newcastle.edu.au/library/access/subject-research-guides',
'https://libguides.atu.edu/',
    'http://researchguides.njit.edu/',
'https://www.concordia.ca/library/guides.html'
    
            ]
    
import pandas as pd 
import csv
from selenium import webdriver  
from selenium.common.exceptions import NoSuchElementException  
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import ElementNotVisibleException
from selenium.common.exceptions import StaleElementReferenceException
import time  
import re
browser = webdriver.Chrome()
def find_all_lib(i):
    
    # 以下是一个subject的内容
        
        browser.get(i)
        time.sleep(2)
        el_category = browser.find_elements_by_css_selector('div.panel.panel-default')[0] # 总是索引第一个
        el_category.find_element_by_css_selector('div.bold').text
        el_category.click()
        time.sleep(2)# 直接这样就可以click了 但也要click才能够索取到下一级的内容
        el_a = el_category.find_elements_by_css_selector('ul.s-lg-guide-list li a')[0] 
        el_a.text, el_a.get_attribute('href')
        el_a.text
    # 用double loop来爬取所有subject的内容
        subjects = []

        el_categories = browser.find_elements_by_css_selector('div.panel.panel-default')
        for el_category in el_categories:
            category = el_category.find_element_by_css_selector('div.bold').text
            el_category.click()
            time.sleep(2)    
            el_as = el_category.find_elements_by_css_selector('ul.s-lg-guide-list li a')
            for el_a in el_as:
                subject = el_a.text
                link = el_a.get_attribute('href')
                subjects.append((category, subject, link))
        s = i.replace('/','-').replace(':','-')
        df = pd.DataFrame(subjects, columns=['Category', 'Subject', 'Link'])
        df.to_csv('{}.csv'.format(s))
        

success_url = []
fail_url = []
for i in url_list:
    try:
        find_all_lib(i)
        success_url.append(i)
        
    except IndexError:
        print('IndexError on URL:', i)
        fail_url.append(i)  
    
    except ElementNotVisibleException:
        print('ElementNotVisibleExceptio:', i)
        fail_url.append(i)
    except StaleElementReferenceException:
        print('StaleElementReferenceException:', i)
        fail_url.append(i)
    except WebDriverException:
        print('WebDriverException:', i)
        fail_url.append(i)

df = pd.DataFrame(success_url)
df.to_csv('index_success_url.csv')

dfs = pd.DataFrame(fail_url)
dfs.to_csv('index_fail_url.csv')

https://libguides.unm.edu/
# Out:
# WebDriverException: https://libguides.unm.edu/
# IndexError on URL: https://library.worc.ac.uk/subject-guides
# IndexError on URL: https://www.library.ucdavis.edu/browse-subjects/
# IndexError on URL: https://libguides.mmu.ac.uk/subjectguides
# IndexError on URL: https://www.gcu.ac.uk/library/subjecthelp/subjectguides/
# IndexError on URL: https://targetcareers.co.uk/uni/degree-subject-guides
# IndexError on URL: http://www.sussex.ac.uk/library/guides
# IndexError on URL: https://lib.de.us/subject-guides/
# IndexError on URL: https://www.topuniversities.com/qs-world-university-rankings
# IndexError on URL: https://www.thecompleteuniversityguide.co.uk/league-tables/rankings
# IndexError on URL: https://www.thecompleteuniversityguide.co.uk/
# IndexError on URL: https://libguides.uwc.ac.za/
# IndexError on URL: https://library.soton.ac.uk/home/subjects
# IndexError on URL: http://www.library.manchester.ac.uk/search-resources/subject-guides/
# ...

# %%
# similar with columbia
https://libguides.mmu.ac.uk/subjectguides
https://www.gcu.ac.uk/library/subjecthelp/subjectguides/
http://www.sussex.ac.uk/library/guides
https://libguides.uwc.ac.za/?b=g&d=a
https://library.soton.ac.uk/home/subjects

# %%
# 8 universities in HK

import pandas as pd 
url_list = [
    

    'https://researchguides.uic.edu',
                'https://libguides.rhul.ac.uk/',

  
# http://libguides.ln.edu.hk/databases/   # 岭南
# http://libguides.lb.polyu.edu.hk/#sthash.5jpN99v0.dpbs
# http://library.ust.hk/collections-resources/guides-to-resources/subject-guides/
# http://libguides.library.cityu.edu.hk/home
# https://www.lib.eduhk.hk/instruct/guides/index.html

    
           ]
import pandas as pd 
import csv
from selenium import webdriver  
from selenium.common.exceptions import NoSuchElementException  
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import ElementNotVisibleException
from selenium.common.exceptions import StaleElementReferenceException
import time  
import re
browser = webdriver.Chrome()
def find_all_lib(i):
    
    # 以下是一个subject的内容
        
        browser.get(i)
        time.sleep(5)
        el_category = browser.find_elements_by_css_selector('div.panel.panel-default')[0] # 总是索引第一个
        el_category.find_element_by_css_selector('div.bold').text
        el_category.click()
        time.sleep(5)# 直接这样就可以click了 但也要click才能够索取到下一级的内容
        el_a = el_category.find_elements_by_css_selector('ul.s-lg-guide-list li a')[0] 
        el_a.text, el_a.get_attribute('href')
        el_a.text
    # 用double loop来爬取所有subject的内容
        subjects = []

        el_categories = browser.find_elements_by_css_selector('div.panel.panel-default')
        for el_category in el_categories:
            category = el_category.find_element_by_css_selector('div.bold').text
            el_category.click()
            time.sleep(5)    
            el_as = el_category.find_elements_by_css_selector('ul.s-lg-guide-list li a')
            for el_a in el_as:
                subject = el_a.text
                link = el_a.get_attribute('href')
                subjects.append((category, subject, link))
        s = i.replace('/','-').replace(':','-')
        df = pd.DataFrame(subjects, columns=['Category', 'Subject', 'Link'])
        df.to_csv('{}.csv'.format(s))
        

success_url = []
fail_url = []
for i in url_list:
    try:
        find_all_lib(i)
        success_url.append(i)
        
    except IndexError:
        print('IndexError on URL:', i)
        fail_url.append(i)  
    
    except ElementNotVisibleException:
        print('ElementNotVisibleExceptio:', i)
        fail_url.append(i)
    except StaleElementReferenceException:
        print('StaleElementReferenceException:', i)
        fail_url.append(i)
    except WebDriverException:
        print('WebDriverException:', i)
        fail_url.append(i)

df = pd.DataFrame(success_url)
df.to_csv('index_success_url.csv')

dfs = pd.DataFrame(fail_url)
dfs.to_csv('index_fail_url.csv')
# Out:
# WebDriverException: https://researchguides.uic.edu
# StaleElementReferenceException: https://libguides.rhul.ac.uk/

# %%
# UCL Library，special case

from selenium import webdriver  
from selenium.common.exceptions import NoSuchElementException  
import time  
import re
browser = webdriver.Chrome()

# 以下是一个subject的内容
browser.get('https://www.ucl.ac.uk/library/subject-support/guides')
el_category = browser.find_elements_by_css_selector('ul.toc li a')[0] # 总是索引第一个
el_category.text
el_category.click() 
browser.execute_script('window.scrollTo(0, document.body.scrollHeight/2.5);')
el_a = browser.find_elements_by_css_selector('ul.disc li a')[0] # 这里不是el_category
el_a.text, el_a.get_attribute('href') # 

subjects = []

el_categories = browser.find_elements_by_css_selector('ul.toc')
for el_category in el_categories:
    category = el_category.find_element_by_css_selector('ul.toc li a').text
    
    el_category.click()
    time.sleep(1)
    
    el_as = el_category.find_elements_by_css_selector('ul.disc li a')
    for el_a in el_as:
        subject = el_a.text
        link = el_a.get_attribute('href')

        subjects.append((category, subject, link))
        
df_utexas = pd.DataFrame(subjects, columns=['Category', 'Subject', 'Link'])
df_utexas.head()
df_utexas.tail()
df_utexas

# %%
# Out:
# IndexError on URL: https://libguides.depaul.edu/
# StaleElementReferenceException: https://guides.lib.vt.edu/
